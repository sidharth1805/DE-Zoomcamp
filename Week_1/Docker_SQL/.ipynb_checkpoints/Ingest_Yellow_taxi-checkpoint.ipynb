# %%
import pandas as pd

# %%
df=pd.read_parquet('E:\DE\Zoomcamp\yellow_tripdata_2022-01.parquet', engine='pyarrow')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
x_df=df.head(100)

# %%
x_df.to_csv('sample.csv')

# %%
df=pd.read_csv('sample.csv')

# %%
x_df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1          1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2          2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3          2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4          2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ..       ...                  ...                   ...              ...
# 95         1  2022-01-01 00:32:27   2022-01-01 00:39:38              3.0
# 96         1  2022-01-01 00:43:15   2022-01-01 01:01:35              1.0
# 97         2  2022-01-01 00:15:35   2022-01-01 00:20:49              2.0
# 98         2  2022-01-01 00:32:24   2022-01-01 00:34:54              1.0
# 99         2  2022-01-01 00:40:45   2022-01-01 00:47:22              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
print(pd.io.sql.get_schema(x_df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
df_iter=pd.read_parquet('E:\DE\Zoomcamp\yellow_tripdata_2022-01.parquet', engine='pyarrow')

# %%
x_df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
x_df.head(n=0).to_sql(name='yellow_taxi_data',con=engine, if_exists='replace')

# %%
import pyarrow.parquet as pq

pfile = pq.ParquetFile('E:\DE\Zoomcamp\yellow_tripdata_2022-01.parquet')

# %%
count=0
for table in pfile.iter_batches(batch_size=100000):
    df = table.to_pandas()
    count+=1
    print('Inserting chunk no #%.3f' % count)
    df.to_sql(name='yellow_taxi_data',con=engine,if_exists='append')
# Out:
# Inserting chunk no #1.000
# Inserting chunk no #2.000
# Inserting chunk no #3.000
# Inserting chunk no #4.000
# Inserting chunk no #5.000
# Inserting chunk no #6.000
# Inserting chunk no #7.000
# Inserting chunk no #8.000
# Inserting chunk no #9.000
# Inserting chunk no #10.000
# Inserting chunk no #11.000
# Inserting chunk no #12.000
# Inserting chunk no #13.000
# Inserting chunk no #14.000
# Inserting chunk no #15.000
# Inserting chunk no #16.000
# Inserting chunk no #17.000
# Inserting chunk no #18.000
# Inserting chunk no #19.000
# Inserting chunk no #20.000
# Inserting chunk no #21.000
# Inserting chunk no #22.000
# Inserting chunk no #23.000
# Inserting chunk no #24.000
# Inserting chunk no #25.000
